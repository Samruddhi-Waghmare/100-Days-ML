# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('placement.csv',index_col=0)

# %%
df.sample(5)
# Out:
#     cgpa     iq  placement
# 81   5.4  107.0          0
# 3    7.4  132.0          1
# 71   6.1  132.0          1
# 49   5.4  135.0          0
# 86   5.1  128.0          0

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['cgpa'],kde=True)

plt.subplot(1,2,2)
sns.histplot(df['iq'], kde=True)

plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_457980\4183688368.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'],kde=True)

# %%
print("Mean value of cgpa",df['cgpa'].mean())
print("Std value of cgpa",df['cgpa'].std())
print("Min value of cgpa",df['cgpa'].min())
print("Max value of cgpa",df['cgpa'].max())
# Out:
# Mean value of cgpa 5.9910000000000005
# Std value of cgpa 1.1436336737775692
# Min value of cgpa 3.3
# Max value of cgpa 8.5

# %%
# find the boundary values
print("Highest allowed",df['cgpa'].mean() + 3*df['cgpa'].std())
print("Lowest allowed",df['cgpa'].mean() - 3*df['cgpa'].std())
# Out:
# Highest allowed 9.421901021332708
# Lowest allowed 2.560098978667293

# %%
# Finding the outliers
df[(df['cgpa']>41) | (df['cgpa']< 1)]
# Out:
# Empty DataFrame
# Columns: [cgpa, iq, placement]
# Index: []

# %%
# trimming 
new_df = df[(df['cgpa']<8.80) & (df['cgpa']>5.11)]
new_df
# Out:
#     cgpa     iq  placement
# 0    6.8  123.0          1
# 1    5.9  106.0          0
# 2    5.3  121.0          0
# 3    7.4  132.0          1
# 4    5.8  142.0          0
# ..   ...    ...        ...
# 92   5.2  110.0          0
# 93   6.8  112.0          1
# 97   6.7  182.0          1
# 98   6.3  103.0          1
# 99   6.2  113.0          1
#
# [72 rows x 3 columns]

# %%
# capping 
# max and min se bahar nahi jane dene
upper_limit df['cgpa'].mean() + 3*df['cgpa'].std()
lower_limit df['cgpa'].mean() - 3*df['cgpa'].std()
# Out:
#   Cell In[25], line 3
#     upper_limit df['cgpa'].mean() + 3*df['cgpa'].std()
#                 ^
# SyntaxError: invalid syntax

# %%
lower_limit

# %%
df['cgpa'] = np.where (
    df['cgpa']>upper_limit,
    upper_limit,
    np.where(
        df['cgpa']>lower_limit,
        lower_limit,
        df['cgpa']
    )
)
