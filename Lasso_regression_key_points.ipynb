# %%
from sklearn.datasets import load_diabetes

import numpy as np
import pandas as pd

import matplotlib.pyplot as plt

from sklearn.linear_model import Lasso
from sklearn.metrics import r2_score

from sklearn.model_selection import train_test_split

# %%
data = load_diabetes()

df = pd.DataFrame(data.data, columns=data.feature_names)
df['TARGET'] = data.target

df.head()
# Out:
#         age       sex       bmi        bp        s1        s2        s3  \
# 0  0.038076  0.050680  0.061696  0.021872 -0.044223 -0.034821 -0.043401
# 1 -0.001882 -0.044642 -0.051474 -0.026328 -0.008449 -0.019163  0.074412
# 2  0.085299  0.050680  0.044451 -0.005670 -0.045599 -0.034194 -0.032356
# 3 -0.089063 -0.044642 -0.011595 -0.036656  0.012191  0.024991 -0.036038
# 4  0.005383 -0.044642 -0.036385  0.021872  0.003935  0.015596  0.008142
#
#          s4        s5        s6  TARGET
# 0 -0.002592  0.019907 -0.017646   151.0
# 1 -0.039493 -0.068332 -0.092204    75.0
# 2 -0.002592  0.002861 -0.025930   141.0
# 3  0.034309  0.022688 -0.009362   206.0
# 4 -0.002592 -0.031988 -0.046641   135.0

# %%
X_train, X_test, y_train, y_test = train_test_split(data.data, data.target, test_size=0.2,random_state=2)

# %%
coefs = []
r2_scores = []

for i in [0,0.1,1,10]:
    reg = Lasso(alpha=i)
    reg.fit(X_train,y_train)
    
    coefs.append(reg.coef_.tolist())
    y_pred = reg.predict(X_test)
    r2_scores.append(r2_score(y_test,y_pred))
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)

# %%
plt.figure(figsize=(14,9))
plt.subplot(221)
plt.bar(data.feature_names,coefs[0])
plt.title('Alpha = 0,r2_score ={}'.format(round(r2_scores[0],2)))

plt.subplot(222)
plt.bar(data.feature_names,coefs[1])
plt.title('Alpha =0.1, r2_score = {}'.format(round(r2_scores[1],2)))

plt.subplot(223)
plt.bar(data.feature_names,coefs[2])
plt.title('Alpha =1, r2_score = {}'.format(round(r2_scores[1],2)))

plt.subplot(224)
plt.bar(data.feature_names,coefs[3])
plt.title('Alpha =10, r2_score = {}'.format(round(r2_scores[3],2)))

plt.show()

# %%
alphas = [0,0.0001,0.001,0.01,0.1,1,10,100,1000,10000]

coefs= []

for i in alphas:
    reg = Lasso(alpha=i)
    reg.fit(X_train,y_train)

    coefs.append(reg.coef_.tolist())
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)

# %%
input_array = np.array(coefs)

coef_df = pd.DataFrame(input_array, columns=data.feature_names)
coef_df['alpha'] = alphas
coef_df.set_index('alpha')
# Out:
#                  age         sex         bmi          bp          s1  \
# alpha
# 0.0000     -9.157778 -205.412964  516.781112  340.597980 -890.752436
# 0.0001     -9.069064 -205.329406  516.789418  340.532379 -888.660904
# 0.0010     -8.262770 -204.205364  517.650073  339.743901 -826.663603
# 0.0100     -1.359721 -192.937180  526.356514  332.641101 -430.226975
# 0.1000      0.000000 -113.969928  526.744396  292.628472  -82.693681
# 1.0000      0.000000    0.000000  363.885742   27.273163    0.000000
# 10.0000     0.000000    0.000000    0.000000    0.000000    0.000000
# 100.0000    0.000000    0.000000    0.000000    0.000000    0.000000
# 1000.0000   0.000000    0.000000    0.000000    0.000000    0.000000
# 10000.0000  0.000000    0.000000    0.000000    0.000000    0.000000
#
#                     s2          s3          s4          s5         s6
# alpha
# 0.0000      557.464984  151.759437  126.112388  859.350316  52.418059
# 0.0001      555.958584  150.593655  125.450143  858.645541  52.380294
# 0.0010      508.617395  120.908607  113.921773  836.320753  52.012849
# 0.0100      191.295480  -44.034913   68.988987  688.396028  47.940616
# 0.1000       -0.000000 -152.685338    0.000000  551.080291   7.170992
# 1.0000        0.000000   -0.000000    0.000000  336.137262   0.000000
# 10.0000       0.000000    0.000000    0.000000    0.000000   0.000000
# 100.0000      0.000000    0.000000    0.000000    0.000000   0.000000
# 1000.0000     0.000000    0.000000    0.000000    0.000000   0.000000
# 10000.0000    0.000000    0.000000    0.000000    0.000000   0.000000

# %%
alphas = [0,0.0001,0.0005,0.001,0.005,0.1,0.5,1,5,10]

coefs= []

for i in alphas:
    reg = Lasso(alpha=i)
    reg.fit(X_train,y_train)

    coefs.append(reg.coef_.tolist())
# Out:
# C:\Users\ADMIN\anaconda3\Lib\site-packages\sklearn\base.py:1403: UserWarning: With alpha=0, this algorithm does not converge well. You are advised to use the LinearRegression estimator
#   return fit_method(estimator, *args, **kwargs)

# %%
input_array = np.array(coefs).T

plt.figure(figsize=(15,8))
plt.plot(alphas,np.zeros(len(alphas)),color='black',linewidth=5)
for i in range(input_array.shape[0]):
    plt.plot(alphas,input_array[i],label=data.feature_names[i])
plt.legend()

# %%
m = 100
X = 5 * np.random.rand(m,1) -2
y = 0.7 * X ** 2 - 2*X + 3+ np.random.randn(m,1)

plt.scatter(X,y)
plt.show()

# %%
X_train, X_test, y_train, y_test = train_test_split(X.reshape(100,1), y.reshape(100), test_size=0.2,random_state=2)

# %%
from sklearn.preprocessing import PolynomialFeatures
poly = PolynomialFeatures(degree=10)

X_train = poly.fit_transform(X_train)
X_test = poly.transform(X_test)

# %%
# !pip install mlxtend
# Out:
# Requirement already satisfied: mlxtend in c:\users\admin\anaconda3\lib\site-packages (0.25.0)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\admin\anaconda3\lib\site-packages (from mlxtend) (1.16.3)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\admin\anaconda3\lib\site-packages (from mlxtend) (2.3.5)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\admin\anaconda3\lib\site-packages (from mlxtend) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\admin\anaconda3\lib\site-packages (from mlxtend) (1.9.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\admin\anaconda3\lib\site-packages (from mlxtend) (3.11.1)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\admin\anaconda3\lib\site-packages (from mlxtend) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (0.11.0)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (25.0)
# Requirement already satisfied: pillow>=9 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend) (1.17.0)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (2.7.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn>=1.8.0->mlxtend) (3.5.0)

# %%
import mlxtend
import mlxtend.evaluate as ev

print("Version:", mlxtend.__version__)
print("Location:", mlxtend.__file__)
print(dir(ev))
# Out:
# Version: 0.25.0
# Location: C:\Users\ADMIN\anaconda3\Lib\site-packages\mlxtend\__init__.py
# ['BootstrapOutOfBag', 'GroupTimeSeriesSplit', 'PredefinedHoldoutSplit', 'RandomHoldoutSplit', '__all__', '__builtins__', '__cached__', '__doc__', '__file__', '__loader__', '__name__', '__package__', '__path__', '__spec__', 'accuracy', 'accuracy_score', 'bias_variance_decomp', 'bootstrap', 'bootstrap_outofbag', 'bootstrap_point632', 'bootstrap_point632_score', 'cochrans_q', 'combined_ftest_5x2cv', 'confusion_matrix', 'counterfactual', 'create_counterfactual', 'f_test', 'feature_importance', 'feature_importance_permutation', 'ftest', 'holdout', 'lift_score', 'mcnemar', 'mcnemar_table', 'mcnemar_tables', 'paired_ttest_5x2cv', 'paired_ttest_kfold_cv', 'paired_ttest_resampled', 'permutation', 'permutation_test', 'proportion_difference', 'scoring', 'time_series', 'ttest']

# %%
# %pip uninstall -y mlxtend
# %pip install mlxtend==0.25.0
# Out:
# Found existing installation: mlxtend 0.25.0
# Uninstalling mlxtend-0.25.0:
#   Successfully uninstalled mlxtend-0.25.0
# Note: you may need to restart the kernel to use updated packages.
# Collecting mlxtend==0.25.0
#   Using cached mlxtend-0.25.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: scipy>=1.16.3 in c:\users\admin\anaconda3\lib\site-packages (from mlxtend==0.25.0) (1.16.3)
# Requirement already satisfied: numpy>=2.3.5 in c:\users\admin\anaconda3\lib\site-packages (from mlxtend==0.25.0) (2.3.5)
# Requirement already satisfied: pandas>=2.3.3 in c:\users\admin\anaconda3\lib\site-packages (from mlxtend==0.25.0) (2.3.3)
# Requirement already satisfied: scikit-learn>=1.8.0 in c:\users\admin\anaconda3\lib\site-packages (from mlxtend==0.25.0) (1.9.0)
# Requirement already satisfied: matplotlib>=3.10.8 in c:\users\admin\anaconda3\lib\site-packages (from mlxtend==0.25.0) (3.11.1)
# Requirement already satisfied: joblib>=1.5.2 in c:\users\admin\anaconda3\lib\site-packages (from mlxtend==0.25.0) (1.5.2)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend==0.25.0) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend==0.25.0) (0.11.0)
# Requirement already satisfied: fonttools>=4.28.2 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend==0.25.0) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend==0.25.0) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend==0.25.0) (25.0)
# Requirement already satisfied: pillow>=9 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend==0.25.0) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend==0.25.0) (3.2.5)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\admin\anaconda3\lib\site-packages (from matplotlib>=3.10.8->mlxtend==0.25.0) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend==0.25.0) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\admin\anaconda3\lib\site-packages (from pandas>=2.3.3->mlxtend==0.25.0) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\users\admin\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.10.8->mlxtend==0.25.0) (1.17.0)
# Requirement already satisfied: narwhals>=2.0.1 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn>=1.8.0->mlxtend==0.25.0) (2.7.0)
# Requirement already satisfied: threadpoolctl>=3.5.0 in c:\users\admin\anaconda3\lib\site-packages (from scikit-learn>=1.8.0->mlxtend==0.25.0) (3.5.0)
# Using cached mlxtend-0.25.0-py3-none-any.whl (1.4 MB)
# Installing collected packages: mlxtend
# Successfully installed mlxtend-0.25.0
# Note: you may need to restart the kernel to use updated packages.

# %%
from mlxtend.evaluate import bias_variance_decomp
print("Import successful!")
# Out:
# Import successful!

# %%
import numpy as np
from sklearn.linear_model import Lasso
from mlxtend.evaluate import bias_variance_decomp
alphas = np.linspace(0,30,100)

loss = []
bias = []
varience = []

for i in alphas:
    reg =Lasso(alpha=i)
    avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
        reg,
        X_train,
        X_test, 
        y_train, 
        y_test,
        loss='mse',
        random_seed = 123
    )
    loss.append(avg_expected_loss)
    bias.append(avg_bias)
    varience.append(avg_var)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[25], line 12
#      10 for i in alphas:
#      11     reg =Lasso(alpha=i)
# ---> 12     avg_expected_loss, avg_bias, avg_var = bias_variance_decomp(
#      13         reg,
#      14         X_train,
#      15         X_test,
#      16         y_train,
#      17         y_test,
#      18         loss='mse',
#      19         random_seed = 123
#      20     )
#      21     loss.append(avg_expected_loss)
#      22     bias.append(avg_bias)
#
# File ~\anaconda3\Lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:113, in bias_variance_decomp(estimator, X_train, y_train, X_test, y_test, loss, num_rounds, random_seed, **fit_params)
#     110 all_pred = np.zeros((num_rounds, y_test.shape[0]), dtype=dtype)
#     112 for i in range(num_rounds):
# --> 113     X_boot, y_boot = _draw_bootstrap_sample(rng, X_train, y_train)
#     115     # Keras support
#     116     if estimator.__class__.__name__ in ["Sequential", "Functional"]:
#     117         # reset model
#
# File ~\anaconda3\Lib\site-packages\mlxtend\evaluate\bias_variance_decomp.py:16, in _draw_bootstrap_sample(rng, X, y)
#      12 sample_indices = np.arange(X.shape[0])
#      13 bootstrap_indices = rng.choice(
#      14     sample_indices, size=sample_indices.shape[0], replace=True
#      15 )
# ---> 16 return X[bootstrap_indices], y[bootstrap_indices]
#
# IndexError: index 66 is out of bounds for axis 0 with size 20

# %%
from sklearn.datasets import make_regression

X,y = make_regression(n_samples = 100, n_features=1, n_informative=1, n_targets=1, noise=20, random_state=13)

plt.scatter(X,y)

from sklearn.linear_model import LinearRegression

reg = LinearRegression()
reg.fit(X,y)
print(reg.coef_)
print(reg.intercept_)
# Out:
# [27.82809103]
# -2.29474455867698

# %%
def cal_loss(m,alpha):
    return np.sum((y - m*X.ravel() + 2.29)**2) + alpha*abs(m)

# %%
def predict(m):
    return m*X - 2.29

# %%
m = np.linspace(-45,100,100)
plt.figure(figsize=(12,12))
for j in [0,100,500,1000,2500]:
    loss = []
    for i in range(m.shape[0]):
        loss_i = cal_loss(m[i],j)
        loss.append(loss_i)
    plt.plot(m,loss,label='alpha = {}'.format(j))
plt.legend()
plt.xlabel('Alpha')
plt.ylabel('Loss')
plt.show()
