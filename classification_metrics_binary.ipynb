# %% [markdown]
# ### Defining `y_test` and `y_pred1`
#
# To define `y_test` (the true labels for the test set) and `y_pred1` (the predicted labels from the model), we first need to perform a basic machine learning workflow:
#
# 1.  **Load Data**: Load a dataset.
# 2.  **Prepare Data**: Separate features (X) and target (y).
# 3.  **Split Data**: Divide the data into training and testing sets.
# 4.  **Train Model**: Train a Logistic Regression model on the training data.
# 5.  **Make Predictions**: Use the trained model to predict on the test data, which will give us `y_pred1`.

# %%
# 1. Load Data
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler

# Load a sample dataset (California Housing dataset for demonstration)
df = pd.read_csv('/content/sample_data/california_housing_train.csv')

# Display the first few rows to understand the data
print("Original Data Head:")
display(df.head())
# Out:
# Original Data Head:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income  median_house_value
# 0      1015.0       472.0         1.4936             66900.0
# 1      1129.0       463.0         1.8200             80100.0
# 2       333.0       117.0         1.6509             85700.0
# 3       515.0       226.0         3.1917             73400.0
# 4       624.0       262.0         1.9250             65500.0

# %%
# 2. Prepare Data: Convert a regression problem to a binary classification for Logistic Regression
# Let's say our target is 'median_house_value'. We'll convert it into a binary class (e.g., above/below median)
median_value = df['median_house_value'].median()
df['target_class'] = (df['median_house_value'] > median_value).astype(int)

X = df.drop(['median_house_value', 'target_class'], axis=1) # Features
y = df['target_class'] # Target

print("Features (X) Head:")
display(X.head())
print("Target (y) Head:")
display(y.head())
# Out:
# Features (X) Head:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -114.31     34.19                15.0       5612.0          1283.0
# 1    -114.47     34.40                19.0       7650.0          1901.0
# 2    -114.56     33.69                17.0        720.0           174.0
# 3    -114.57     33.64                14.0       1501.0           337.0
# 4    -114.57     33.57                20.0       1454.0           326.0
#
#    population  households  median_income
# 0      1015.0       472.0         1.4936
# 1      1129.0       463.0         1.8200
# 2       333.0       117.0         1.6509
# 3       515.0       226.0         3.1917
# 4       624.0       262.0         1.9250
# Target (y) Head:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: target_class, dtype: int64

# %%
# Scale numerical features
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)
X_scaled_df = pd.DataFrame(X_scaled, columns=X.columns)

print("Scaled Features (X_scaled_df) Head:")
display(X_scaled_df.head())
# Out:
# Scaled Features (X_scaled_df) Head:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0   2.619365 -0.671520           -1.079671     1.361695        1.764204
# 1   2.539569 -0.573264           -0.761872     2.296608        3.230441
# 2   2.494683 -0.905463           -0.920772    -0.882462       -0.866956
# 3   2.489696 -0.928857           -1.159121    -0.524186       -0.480230
# 4   2.489696 -0.961609           -0.682422    -0.545747       -0.506328
#
#    population  households  median_income
# 0   -0.361184   -0.075998      -1.252543
# 1   -0.261865   -0.099404      -1.081483
# 2   -0.955354   -0.999252      -1.170105
# 3   -0.796793   -0.715774      -0.362600
# 4   -0.701830   -0.622148      -1.026454

# %%
# 3. Split Data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(X_scaled_df, y, test_size=0.3, random_state=42)

print(f"Shape of X_train: {X_train.shape}")
print(f"Shape of X_test: {X_test.shape}")
print(f"Shape of y_train: {y_train.shape}")
print(f"Shape of y_test: {y_test.shape}")
# Out:
# Shape of X_train: (11900, 8)
# Shape of X_test: (5100, 8)
# Shape of y_train: (11900,)
# Shape of y_test: (5100,)

# %%
# 4. Train a Logistic Regression Model
model = LogisticRegression(random_state=42)
model.fit(X_train, y_train)

print("Logistic Regression model trained successfully.")
# Out:
# Logistic Regression model trained successfully.

# %%
# 5. Make Predictions
y_pred1 = model.predict(X_test)

print("Predictions (y_pred1) Head:")
display(y_pred1[:5])
print(f"Shape of y_pred1: {y_pred1.shape}")

print("\nNow y_test and y_pred1 are defined and ready for evaluation in the next cell.")
# Out:
# Predictions (y_pred1) Head:
# array([0, 1, 0, 0, 0])
# Shape of y_pred1: (5100,)
#
# Now y_test and y_pred1 are defined and ready for evaluation in the next cell.

# %%
import pandas as pd
from sklearn.metrics import confusion_matrix, recall_score, precision_score, f1_score

print("For Logistic regression Model")
print("-"*50)
cdf = pd.DataFrame(confusion_matrix(y_test, y_pred1),columns=list(range(0,2)))
print(cdf)
print("-"*50)
print("precision -", precision_score(y_test, y_pred1))
print("recall -", recall_score(y_test, y_pred1))
print("f1 -", f1_score(y_test, y_pred1))
# Out:
# For Logistic regression Model
# --------------------------------------------------
#       0     1
# 0  2073   407
# 1   432  2188
# --------------------------------------------------
# precision - 0.843159922928709
# recall - 0.8351145038167939
# f1 - 0.839117929050815
