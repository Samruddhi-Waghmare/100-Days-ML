# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('placement.csv')

# %%
df.head()
# Out:
#    Unnamed: 0  cgpa     iq  placement
# 0           0   6.8  123.0          1
# 1           1   5.9  106.0          0
# 2           2   5.3  121.0          0
# 3           3   7.4  132.0          1
# 4           4   5.8  142.0          0

# %%
df.shape
# Out:
# (100, 4)

# %%
plt.figure(figsize=(16,5))
plt.subplot(1,2,1)
sns.distplot(df['cgpa'])

plt.subplot(1,2,2)
sns.distplot(df['iq'])

plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_174424\3753503687.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['cgpa'])
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_174424\3753503687.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['iq'])

# %%
df['iq'].skew()
# Out:
# np.float64(0.018095580898964243)

# %%
df['iq'].describe()
# Out:
# count    100.000000
# mean     123.580000
# std       39.944198
# min       37.000000
# 25%      101.500000
# 50%      127.500000
# 75%      149.000000
# max      233.000000
# Name: iq, dtype: float64

# %%
sns.boxplot(df['iq'])
# Out:
# <Axes: ylabel='iq'>

# %%
# finding iqr
percentile25 =df['iq'].quantile(0.25)
percentile75 =df['iq'].quantile(0.75)

# %%
percentile25
# Out:
# np.float64(101.5)

# %%
percentile75
# Out:
# np.float64(149.0)

# %%
iqr = percentile75 - percentile25

# %%
iqr
# Out:
# np.float64(47.5)

# %%
upper_limit = percentile75 + 1.5 * iqr
lower_limit = percentile25 + 1.5 * iqr

# %%
print("Upper Limit",upper_limit)
print("Lower Limit",lower_limit)
# Out:
# Upper Limit 220.25
# Lower Limit 172.75

# %%
df[df['iq']>upper_limit]
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 16          16   5.2  224.0          0
# 50          50   3.5  233.0          0

# %%
df[df['iq']>lower_limit]
# Out:
#     Unnamed: 0  cgpa     iq  placement
# 15          15   5.1  176.0          0
# 16          16   5.2  224.0          0
# 17          17   3.3  183.0          0
# 26          26   7.0  199.0          1
# 50          50   3.5  233.0          0
# 52          52   7.0  175.0          1
# 80          80   4.9  196.0          0
# 95          95   4.3  200.0          0
# 97          97   6.7  182.0          1

# %%
new_df = df[df['iq']<upper_limit]

# %%
new_df.shape
# Out:
# (98, 4)

# %%
# do trimming and capping
