# %%
import numpy as np
import pandas as pd

from sklearn.model_selection import train_test_split

import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('train.csv',usecols=['Age','Survived','Fare'])

# %%
df.head()
# Out:
#    Survived   Age     Fare
# 0         0  22.0   7.2500
# 1         1  38.0  71.2833
# 2         1  26.0   7.9250
# 3         1  35.0  53.1000
# 4         0  35.0   8.0500

# %%
df.isnull().mean() * 100
# Out:
# Survived     0.00000
# Age         19.86532
# Fare         0.00000
# dtype: float64

# %%
X = df.drop(columns=['Survived'])
y= df['Survived']

# %%
X_train,X_test, y_train,y_test = train_test_split(X,y,test_size = 0.2, random_state = 2)

# %%
X_train
# Out:
#       Age      Fare
# 30   40.0   27.7208
# 10    4.0   16.7000
# 873  47.0    9.0000
# 182   9.0   31.3875
# 876  20.0    9.8458
# ..    ...       ...
# 534  30.0    8.6625
# 584   NaN    8.7125
# 493  71.0   49.5042
# 527   NaN  221.7792
# 168   NaN   25.9250
#
# [712 rows x 2 columns]

# %%
X_train['Age_imputed'] = X_train['Age']
X_test['Age_imputed'] = X_test['Age']

# %%
X_test.tail()
# Out:
#       Age     Fare  Age_Age_imputed  Age_imputed
# 89   24.0   8.0500             24.0         24.0
# 80   22.0   9.0000             22.0         22.0
# 846   NaN  69.5500              NaN          NaN
# 870  26.0   7.8958             26.0         26.0
# 251  29.0  10.4625             29.0         29.0

# %%
X_train['Age_imputed'][X_train['Age_imputed'].isnull()] = X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
X_test['Age_imputed'][X_train['Age_imputed'].isnull()] = X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_221328\3071014344.py:1: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   X_train['Age_imputed'][X_train['Age_imputed'].isnull()] = X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_221328\3071014344.py:2: FutureWarning: ChainedAssignmentError: behaviour will change in pandas 3.0!
# You are setting values through chained assignment. Currently this works in certain cases, but when using Copy-on-Write (which will become the default behaviour in pandas 3.0) this will never work to update the original DataFrame or Series, because the intermediate object on which we are setting values will behave as a copy.
# A typical example is when you are setting values in a column of a DataFrame, like:
#
# df["col"][row_indexer] = value
#
# Use `df.loc[row_indexer, "col"] = values` instead, to perform the assignment in a single step and ensure this keeps updating the original `df`.
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
#   X_test['Age_imputed'][X_train['Age_imputed'].isnull()] = X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3812, in Index.get_loc(self, key)
#    3811 try:
# -> 3812     return self._engine.get_loc(casted_key)
#    3813 except KeyError as err:
#
# File pandas/_libs/index.pyx:167, in pandas._libs.index.IndexEngine.get_loc()
#
# File pandas/_libs/index.pyx:173, in pandas._libs.index.IndexEngine.get_loc()
#
# TypeError: '30     False
# 10     False
# 873    False
# 182    False
# 876    False
#        ...
# 534    False
# 584    False
# 493    False
# 527    False
# 168    False
# Name: Age_imputed, Length: 712, dtype: bool' is an invalid key
#
# During handling of the above exception, another exception occurred:
#
# InvalidIndexError                         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1310, in Series.__setitem__(self, key, value)
#    1309 try:
# -> 1310     self._set_with_engine(key, value, warn=warn)
#    1311 except KeyError:
#    1312     # We have a scalar (or for MultiIndex or object-dtype, scalar-like)
#    1313     #  key that is not present in self.index.
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1382, in Series._set_with_engine(self, key, value, warn)
#    1381 def _set_with_engine(self, key, value, warn: bool = True) -> None:
# -> 1382     loc = self.index.get_loc(key)
#    1384     # this is equivalent to self._values[key] = value
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:3824, in Index.get_loc(self, key)
#    3820 except TypeError:
#    3821     # If we have a listlike key, _check_indexing_error will raise
#    3822     #  InvalidIndexError. Otherwise we fall through and re-raise
#    3823     #  the TypeError.
# -> 3824     self._check_indexing_error(key)
#    3825     raise
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6072, in Index._check_indexing_error(self, key)
#    6069 if not is_scalar(key):
#    6070     # if key is not a scalar, directly raise an error (the code below
#    6071     # would convert to numpy arrays and raise later any way) - GH29926
# -> 6072     raise InvalidIndexError(key)
#
# InvalidIndexError: 30     False
# 10     False
# 873    False
# 182    False
# 876    False
#        ...
# 534    False
# 584    False
# 493    False
# 527    False
# 168    False
# Name: Age_imputed, Length: 712, dtype: bool
#
# During handling of the above exception, another exception occurred:
#
# IndexingError                             Traceback (most recent call last)
# Cell In[17], line 2
#       1 X_train['Age_imputed'][X_train['Age_imputed'].isnull()] = X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
# ----> 2 X_test['Age_imputed'][X_train['Age_imputed'].isnull()] = X_train['Age'].dropna().sample(X_train['Age'].isnull().sum()).values
#
# File ~\anaconda3\Lib\site-packages\pandas\core\series.py:1350, in Series.__setitem__(self, key, value)
#    1345     raise KeyError(
#    1346         "key of type tuple not found and not a MultiIndex"
#    1347     ) from err
#    1349 if com.is_bool_indexer(key):
# -> 1350     key = check_bool_indexer(self.index, key)
#    1351     key = np.asarray(key, dtype=bool)
#    1353     if (
#    1354         is_list_like(value)
#    1355         and len(value) != len(self)
#    (...)   1360         #  _where call below
#    1361         # GH#44265
#
# File ~\anaconda3\Lib\site-packages\pandas\core\indexing.py:2698, in check_bool_indexer(index, key)
#    2696 indexer = result.index.get_indexer_for(index)
#    2697 if -1 in indexer:
# -> 2698     raise IndexingError(
#    2699         "Unalignable boolean Series provided as "
#    2700         "indexer (index of the boolean Series and of "
#    2701         "the indexed object do not match)."
#    2702     )
#    2704 result = result.take(indexer)
#    2706 # fall through for boolean
#
# IndexingError: Unalignable boolean Series provided as indexer (index of the boolean Series and of the indexed object do not match).

# %%
X_test['Age_imputed'][X_test['Age_imputed'].isnull()] = \
    X_train['Age'].dropna().sample(X_test['Age'].isnull().sum()).values

# %%
X_train
# Out:
#       Age      Fare  Age_imputed
# 30   40.0   27.7208         40.0
# 10    4.0   16.7000          4.0
# 873  47.0    9.0000         47.0
# 182   9.0   31.3875          9.0
# 876  20.0    9.8458         20.0
# ..    ...       ...          ...
# 534  30.0    8.6625         30.0
# 584   NaN    8.7125         54.0
# 493  71.0   49.5042         71.0
# 527   NaN  221.7792         41.0
# 168   NaN   25.9250         32.0
#
# [712 rows x 3 columns]

# %%
sns.distplot(X_train['Age'],label = 'Original', hist = False)
sns.distplot(X_train['Age_imputed'],label = 'Imputed', hist = False)

plt.legend()
plt.show()
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_221328\1822935074.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['Age'],label = 'Original', hist = False)
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_221328\1822935074.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(X_train['Age_imputed'],label = 'Imputed', hist = False)

# %%
print('Original variable varience',X_train['Age'].var())
print('varience after random imputation',X_train['Age_imputed'].var())
# Out:
# Original variable varience 204.3495133904614
# varience after random imputation 203.86212380410538

# %%
X_train[['Fare','Age','Age_imputed']].cov()
# Out:
#                     Fare         Age  Age_imputed
# Fare         2368.246832   71.512440    58.933013
# Age            71.512440  204.349513   204.349513
# Age_imputed    58.933013  204.349513   203.862124

# %%
X_train[['Age','Age_imputed']].boxplot()
# Out:
# <Axes: >

# %%
observation = X_train.iloc[0]
sampled_value = X_train['Age'].dropna().sample(1,random_state = int(observation['Fare']))
